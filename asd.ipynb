# %% [markdown]
# ## COMANDOS GIT SENCILLOS

# %% [markdown]
# git init
#
# git remote add origin "mi/url"
#
# git status    // para ver qué falta por trackear
#
# git add archivo.xd    // para trackearlo
#
# git commit -m "Nombre del commit"    // para crear un commit
#
# git push    // para subirlo a GitHub
#
# git push --set-upstream origin master   // o main

# %% [markdown]
# LOS 4 ESTADOS
#
# LOCAL
#
# Area de preparacion decido que poner en el commit (git add)
#
# repositorio local (git commit), historial guardado en la maquina
#
# Codigo en la nube (git push)
